# %%
source("libraries.R")
source("dependencies.R")
# Out:
# Installing package into ‘/home/bita/R/x86_64-pc-linux-gnu-library/4.4’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘textshaping’, ‘ragg’
# Error in library(tidyverse): there is no package called ‘tidyverse’
# Traceback:
#
# 1. source("libraries.R")
# 2. withVisible(eval(ei, envir))
# 3. eval(ei, envir)
# 4. eval(ei, envir)
# 5. suppressWarnings({
#  .     install.packages("tidyverse")
#  .     library(tidyverse)
#  .     library(tidymodels)
#  .     library(dplyr)
#  .     library(kableExtra)
#  .     library(readxl)
#  .     library(stats)
#  .     library(BSDA)
#  .     library(ggplot2)
#  .     library(reshape2)
#  .     library(GGally)
#  .     library(robustbase)
#  .     library(knitr)
#  .     library(lars)
#  .     library(caret)
#  .     library(glmnet)
#  . })
# 6. withCallingHandlers(expr, warning = function(w) if (inherits(w,
#  .     classes)) tryInvokeRestart("muffleWarning"))
# 7. library(tidyverse)

# %%
df<-read.csv("df_sudamerica.csv")
head(df)
# Out:
#   Area      Year Savanna.fires Forest.fires Crop.Residues Rice.Cultivation
# 1 Argentina 1990 2779.692      1097.178     1965.499       914.3008
# 2 Argentina 1991 2779.692      1097.178     2144.235       676.3176
# 3 Argentina 1992 2779.692      1097.178     2248.566      1103.0880
# 4 Argentina 1993 2779.692      1097.178     2235.483      1094.8560
# 5 Argentina 1994 2779.692      1097.178     2233.539      1108.1056
# 6 Argentina 1995 2779.692      1097.178     2404.908      1443.4616
#   Drained.organic.soils..CO2. Pesticides.Manufacturing Food.Transport
# 1 5128.514                    689                      2920.126
# 2 5128.514                    699                      3143.701
# 3 5128.514                    631                      3514.505
# 4 5128.514                    571                      3733.810
# 5 5128.514                    693                      3935.743
# 6 5138.312                    872                      4168.870
#   Forestland ⋯ Manure.Management Fires.in.organic.soils
# 1 -40102.73  ⋯ 2173.349          0
# 2 -40102.73  ⋯ 2148.927          0
# 3 -40102.73  ⋯ 2184.396          0
# 4 -40102.73  ⋯ 2177.431          0
# 5 -40102.73  ⋯ 2241.324          0
# 6 -40102.73  ⋯ 2200.746          0
#   Fires.in.humid.tropical.forests On.farm.energy.use Rural.population
# 1 541.3267                        6077.228           4260175
# 2 541.3267                        4813.008           4206419
# 3 541.3267                        6846.902           4192854
# 4 541.3267                        7553.773           4177901
# 5 541.3267                        8927.248           4160961
# 6 541.3267                        9032.746           4141986
#   Urban.population Total.Population...Male Total.Population...Female
# 1 28469564         16063515                16574141
# 2 28987499         16298168                16807594
# 3 29462297         16529209                17039077
# 4 29933016         16757748                17269492
# 5 30397154         16989567                17499129
# 6 30852828         17220607                17725502
#   total_emission Average.Temperature..C
# 1 114303.1        0.3300833
# 2 112979.8        0.1930833
# 3 114888.8       -0.2140833
# 4 115580.6        0.1254167
# 5 118040.6        0.6264167
# 6 118055.0        0.2660000

# %% [markdown]
# # EDA

# %%
dim(df)
# Out:
# [1] 310  31

# %%
sum(is.na(df))
# Out:
# [1] 31

# %%
df_sin_nulos <- na.omit(df)
dim(df_sin_nulos)
# Out:
# [1] 279  31

# %%
# Asegúrate de que las variables categóricas estén como factores
df$Area <- as.factor(df$Area)
df$Year <- as.factor(df$Year)

# Seleccionamos solo las columnas numéricas (las emisiones de CO₂)
df_numeric <- df[, sapply(df, is.numeric)]

# Verificar si hay datos faltantes
summary(df_numeric)
# Out:
#  Savanna.fires       Forest.fires      Crop.Residues      Rice.Cultivation
#  Min.   :    0.13   Min.   :    0.00   Min.   :   10.12   Min.   :  41.94
#  1st Qu.:   15.26   1st Qu.:   10.25   1st Qu.:  123.65   1st Qu.: 466.31
#  Median :   35.90   Median :  122.32   Median :  215.30   Median :1301.58
#  Mean   : 1711.73   Mean   : 1500.97   Mean   : 1358.54   Mean   :1704.00
#  3rd Qu.: 1601.88   3rd Qu.:  514.04   3rd Qu.:  432.57   3rd Qu.:2331.29
#  Max.   :23503.32   Max.   :27663.50   Max.   :13452.46   Max.   :8525.13
#
#  Drained.organic.soils..CO2. Pesticides.Manufacturing Food.Transport
#  Min.   :   0.0              Min.   :   0.00          Min.   :    5.024
#  1st Qu.: 101.6              1st Qu.:  17.25          1st Qu.:  272.509
#  Median : 444.0              Median : 166.00          Median : 1171.260
#  Mean   :1079.4              Mean   :1057.78          Mean   : 3126.688
#  3rd Qu.:1000.4              3rd Qu.: 844.75          3rd Qu.: 2836.303
#  Max.   :5231.4              Max.   :7868.00          Max.   :27613.212
#
#    Forestland        Net.Forest.conversion Food.Household.Consumption
#  Min.   :-519221.8   Min.   :      0       Min.   :   24.79
#  1st Qu.: -27952.3   1st Qu.:   3174       1st Qu.:  130.76
#  Median :  -5283.8   Median :  39973       Median : 1324.98
#  Mean   : -52107.2   Mean   : 160051       Mean   : 2951.17
#  3rd Qu.:   -333.7   3rd Qu.:  83135       3rd Qu.: 3128.65
#  Max.   :      0.0   Max.   :1605106       Max.   :21635.80
#
#   Food.Retail        On.farm.Electricity.Use Food.Packaging
#  Min.   :    0.428   Min.   :   0.025        Min.   :   0.072
#  1st Qu.:   43.461   1st Qu.:   9.984        1st Qu.:  67.631
#  Median :  238.743   Median :  94.234        Median : 129.673
#  Mean   : 1543.880   Mean   : 354.136        Mean   : 673.512
#  3rd Qu.: 1181.084   3rd Qu.: 302.517        3rd Qu.: 638.874
#  Max.   :16052.582   Max.   :4346.010        Max.   :5695.639
#
#  Agrifood.Systems.Waste.Disposal Food.Processing    Fertilizers.Manufacturing
#  Min.   :   72.74                Min.   :   4.078   Min.   :   0.054
#  1st Qu.: 1053.75                1st Qu.: 209.588   1st Qu.: 356.491
#  Median : 4163.99                Median : 401.092   Median : 657.405
#  Mean   :11891.06                Mean   :1548.884   Mean   :1618.257
#  3rd Qu.:10296.70                3rd Qu.:2156.202   3rd Qu.:3331.036
#  Max.   :90686.73                Max.   :9198.803   Max.   :7002.060
#
#       IPPU          Manure.applied.to.Soils Manure.left.on.Pasture
#  Min.   :    3.87   Min.   :    7.944       Min.   :   24.18
#  1st Qu.:  398.80   1st Qu.:  208.754       1st Qu.: 1913.77
#  Median : 2196.43   Median :  498.167       Median : 4181.08
#  Mean   : 7244.33   Mean   : 1371.423       Mean   :13134.72
#  3rd Qu.: 5665.13   3rd Qu.:  984.227       3rd Qu.:10295.62
#  Max.   :59662.08   Max.   :10434.506       Max.   :92630.76
#
#  Manure.Management   Fires.in.organic.soils Fires.in.humid.tropical.forests
#  Min.   :    8.928   Min.   :0              Min.   :    0.000
#  1st Qu.:  430.117   1st Qu.:0              1st Qu.:    0.865
#  Median :  526.459   Median :0              Median :   51.696
#  Mean   : 1754.305   Mean   :0              Mean   : 1351.501
#  3rd Qu.: 1341.026   3rd Qu.:0              3rd Qu.:  332.714
#  Max.   :12894.496   Max.   :0              Max.   :27104.964
#
#  On.farm.energy.use Rural.population   Urban.population
#  Min.   :  173.1    Min.   :  139739   Min.   :   197762
#  1st Qu.:  511.8    1st Qu.:  542223   1st Qu.:  2923365
#  Median :  695.2    Median : 3131420   Median : 11075220
#  Mean   : 3984.3    Mean   : 6454106   Mean   : 27011265
#  3rd Qu.: 3270.0    3rd Qu.: 6970413   3rd Qu.: 30281120
#  Max.   :25387.5    Max.   :38948117   Max.   :186217070
#  NA's   :31
#  Total.Population...Male Total.Population...Female total_emission
#  Min.   :   205650       Min.   :   207106         Min.   : -56242
#  1st Qu.:  1600148       1st Qu.:  1718671         1st Qu.:   9372
#  Median :  7581947       Median :  7625122         Median :  51903
#  Mean   : 16516431       Mean   : 16851668         Mean   : 168506
#  3rd Qu.: 18031028       3rd Qu.: 18397319         3rd Qu.: 126580
#  Max.   :104779288       Max.   :108417015         Max.   :1522722
#
#  Average.Temperature..C
#  Min.   :-0.4288
#  1st Qu.: 0.4054
#  Median : 0.7048
#  Mean   : 0.7139
#  3rd Qu.: 1.0007
#  Max.   : 1.7967

# %%
options(repr.plot.width=12, repr.plot.height=12)

library(corrplot)
corrplot(cor_matrix, method = "color", type = "upper", 
         tl.cex = 0.9, # Tamaño del texto
         tl.col = "black", # Color del texto
         addCoef.col = "black", # Mostrar coeficientes de correlación
         number.cex = 0.5) # Tamaño de los coeficientes
# Out:
# Plot with title “”

# %%
df$Area <- as.factor(df$Area)
df$Year <- as.factor(df$Year)

df_scaled <- df %>%
  mutate(across(where(is.numeric), scale))

head(df_scaled)
# Out:
#   Area      Year Savanna.fires Forest.fires Crop.Residues Rice.Cultivation
# 1 Argentina 1990 0.2975738     -0.09816771  0.2299507     -0.4823964
# 2 Argentina 1991 0.2975738     -0.09816771  0.2976663     -0.6277716
# 3 Argentina 1992 0.2975738     -0.09816771  0.3371932     -0.3670732
# 4 Argentina 1993 0.2975738     -0.09816771  0.3322365     -0.3721018
# 5 Argentina 1994 0.2975738     -0.09816771  0.3314998     -0.3640081
# 6 Argentina 1995 0.2975738     -0.09816771  0.3964248     -0.1591514
#   Drained.organic.soils..CO2. Pesticides.Manufacturing Food.Transport
# 1 2.548872                    -0.18515878              -0.037021021
# 2 2.548872                    -0.18013796               0.003049122
# 3 2.548872                    -0.21427951               0.069505915
# 4 2.548872                    -0.24440441               0.108810682
# 5 2.548872                    -0.18315045               0.145001936
# 6 2.555040                    -0.09327784               0.186783757
#   Forestland ⋯ Manure.Management Fires.in.organic.soils
# 1 0.09574064 ⋯ 0.1310113         NaN
# 2 0.09574064 ⋯ 0.1233759         NaN
# 3 0.09574064 ⋯ 0.1344652         NaN
# 4 0.09574064 ⋯ 0.1322876         NaN
# 5 0.09574064 ⋯ 0.1522633         NaN
# 6 0.09574064 ⋯ 0.1395769         NaN
#   Fires.in.humid.tropical.forests On.farm.energy.use Rural.population
# 1 -0.2009971                      0.3382143          -0.2362174
# 2 -0.2009971                      0.1339211          -0.2420052
# 3 -0.2009971                      0.4625908          -0.2434657
# 4 -0.2009971                      0.5768185          -0.2450757
# 5 -0.2009971                      0.7987670          -0.2468996
# 6 -0.2009971                      0.8158151          -0.2489426
#   Urban.population Total.Population...Male Total.Population...Female
# 1 0.03298613       -0.0173039293           -0.010339044
# 2 0.04470161       -0.0083388696           -0.001641946
# 3 0.05544135        0.0004881915            0.006981762
# 4 0.06608882        0.0092196621            0.015565681
# 5 0.07658743        0.0180764471            0.024120618
# 6 0.08689459        0.0269034700            0.032553956
#   total_emission Average.Temperature..C
# 1 -0.1518168     -0.9083073
# 2 -0.1555233     -1.2325462
# 3 -0.1501761     -2.1961904
# 4 -0.1482386     -1.3926934
# 5 -0.1413483     -0.2069731
# 6 -0.1413081     -1.0599738

# %%
modelo_lineal_scal = df_scaled %>% lm(formula = total_emission~., data = .)
lineal_coef_scal = modelo_lineal_scal %>% tidy(conf.int=TRUE)
# Out:
# Error in `contrasts<-`(`*tmp*`, value = contr.funs[1 + isOF[nn]]): contrasts can be applied only to factors with 2 or more levels
# Traceback:
#
# 1. df_scaled %>% lm(formula = total_emission ~ ., data = .)
# 2. lm(formula = total_emission ~ ., data = .)
# 3. model.matrix(mt, mf, contrasts)
# 4. model.matrix.default(mt, mf, contrasts)
# 5. `contrasts<-`(`*tmp*`, value = contr.funs[1 + isOF[nn]])
# 6. stop("contrasts can be applied only to factors with 2 or more levels")
